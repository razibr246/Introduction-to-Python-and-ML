# %% [markdown]
# Logical Operator

# %%
x = 8; y = 7;z = 3

result = (x > y) and ( x > z)

print(result)
# Out:
# True

# %%
x = 8; y = 9;z = 3

result = (x > y) and ( x > z)

print(result)
# Out:
# False

# %%
x = 8; y = 7;z = 3

result = (x > y) or ( x > z)

print(result)
# Out:
# True

# %%
x = 8; y = 7;z = 3

result = (x > y) and ( x < z)

print(result)
# Out:
# False

# %% [markdown]
# Precedence and Associativity

# %%
eq = 10 + 10/2 - 5*2 # precedency maintain korbe
print(eq)

eq = (10+10)/2 - 5*2 ## ekhane bracket e part tuku ageh compute hobe 

print(eq)
# Out:
# 5.0
# 0.0

# %% [markdown]
# F. Digits Summation codeforces problem

# %%
inp = input()
numbers = inp.split()

n = int(numbers[0])
m = int(numbers[1])


last_digit_of_n = n%10
last_digit_of_m = m%10

print(last_digit_of_n + last_digit_of_m)
# Out:
# 5
