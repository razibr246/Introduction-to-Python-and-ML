# %% [markdown]
# ### Tuple

# %%
# integer tuple
tup = (10, 20, 30, 40)
print("Tuple:", tup,type(tup))


# float tuple
float_tup = (10.5, 10.2)
print("\nFloat Tuple:", float_tup,type(float_tup))


# mixed tuple
mixed_tup = (10, 10.5, "str", True)
print("\nMixed Tuple:", mixed_tup,type(mixed_tup))
# Out:
# Tuple: (10, 20, 30, 40) <class 'tuple'>
#
# Float Tuple: (10.5, 10.2) <class 'tuple'>
#
# Mixed Tuple: (10, 10.5, 'str', True) <class 'tuple'>

# %%
tup1 = (10)

print(tup1,type(tup1))

tup1 = tuple([10])

print(tup1,type(tup1))


tup1 = tuple[10]

print(tup1,type(tup1))

lst = [10, 34, 234]

tup = tuple(lst)

print("Original list:", lst)
print("Type of list:", type(lst))

print("\nConverted tuple:", tup)
print("Type of tuple:", type(tup))
# Out:
# 10 <class 'int'>
# (10,) <class 'tuple'>
# tuple[10] <class 'types.GenericAlias'>
# Original list: [10, 34, 234]
# Type of list: <class 'list'>
#
# Converted tuple: (10, 34, 234)
# Type of tuple: <class 'tuple'>

# %%
#Access

tup = (13,234.8,45,"min",23.4,False)

#index
print(tup[3])

#sliching

new_tup = tup[0:4]

print(new_tup)
# Out:
# min
# (13, 234.8, 45, 'min')

# %%
#mutablity

lst = [0,2,4,5,45]
print(lst)

lst.append(456)

lst[2] = 98374
print(lst)

#immutable

tup = (10,34,34,234,234)
#|tup[2]=77
#print(tup)
# Out:
# [0, 2, 4, 5, 45]
# [0, 2, 98374, 5, 45, 456]

# %%
#tupe method

tup =(34,23423,45,56456664,7,45,45)

print(tup.count(45))
print(tup.index(7))

# %% [markdown]
# ### set

# %%
A = {1,2,4}

print(type(A),A)
# Out:
# <class 'set'> {1, 2, 4}

# %%
B = []

print(type(B))


C = ()

print(type(C))


D = {}

print(type(D))

G = set()

print(type(G))
# Out:
# <class 'list'>
# <class 'tuple'>
# <class 'dict'>
# <class 'set'>

# %%
s = {1,6,1,3,2,7,45,35,6}

print(s)



if (2 in s ):
    print("2 is there")
else:
    print("not there")


sum = 0

for element in s:
    sum += element
print(sum)
# Out:
# {1, 2, 3, 35, 6, 7, 45}
# 2 is there
# 99

# %%
#mutable

s= {5, 1 , 2 ,4, 3} 

s.add(10) 
s.add(0)

print(s)

s.pop()
s.pop()
print(s)

s.remove(5) 

print(s)
# Out:
# {0, 1, 2, 3, 4, 5, 10}
# {2, 3, 4, 5, 10}
# {2, 3, 4, 10}

# %%
a = { 1, 2, 3 } 
b = {1, 2 , 5,6, 4 } 

print( a.union(b) )
print( b.union(a) )

print(a.intersection(b)) 


print(a.isdisjoint(b)) 


print(a.issubset(b))
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6}
# {1, 2}
# False
# False

# %% [markdown]
# ### Dictoreries in python

# %%
#empty

dic = {}

print(type(dic))


dc = { "name": "Razib" , "age" : 22, "address" : " Dhamrai","phone" : [1,9,23,35],"age" : 23}

print(dc)
# Out:
# <class 'dict'>
# {'name': 'Razib', 'age': 23, 'address': ' Dhamrai', 'phone': [1, 9, 23, 35]}

# %%
#access 
#dc_name[key]

print(dc["phone"])

print(dc.get("age"))

dc["name"] = "Razib Miah"

print(dc)
# Out:
# [1, 9, 23, 35]
# 22
# {'name': 'Razib Miah', 'age': 22, 'address': ' Dhamrai', 'phone': [1, 9, 23, 35]}

# %%
print(dc)

print(dc.get("math_marks",55))
# Out:
# {'name': 'Razib', 'age': 23, 'address': ' Dhamrai', 'phone': [1, 9, 23, 35]}
# 55

# %% [markdown]
# ## INterating over Dictinary

# %%
dic ={ "name" : "Phitron" , "age": 20 , "address" : "Dhaka" , "numbers":[10,20,30],"age":30}

keys = dic.keys()

print(keys)

dic["math_numebers"] = 30 

print(keys) 

values = dic.values() 

print(values) 

dic["math_numebers"] = 40 
print(values) 

items = dic.items() 

print(items)
# Out:
# dict_keys(['name', 'age', 'address', 'numbers'])
# dict_keys(['name', 'age', 'address', 'numbers', 'math_numebers'])
# dict_values(['Phitron', 30, 'Dhaka', [10, 20, 30], 30])
# dict_values(['Phitron', 30, 'Dhaka', [10, 20, 30], 40])
# dict_items([('name', 'Phitron'), ('age', 30), ('address', 'Dhaka'), ('numbers', [10, 20, 30]), ('math_numebers', 40)])

# %%
# iteration 
for key,value in dic.items():
    print(key,value)
# Out:
# name Phitron
# age 30
# address Dhaka
# numbers [10, 20, 30]
# math_numebers 40

# %% [markdown]
# ### dictinary comprehension

# %%
square = {x:x**2  for x in range(1,11) if x%2==0}

print(square)
# Out:
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
Co_ordinates = [(10,10.5),(20.5,192) , ( 101,102) ]
Locations =["dhaka" , "chattogram" , "sylhet"]

exact_location = {co_or : loc for co_or, loc in zip(Co_ordinates,Locations)}

print(exact_location)
# Out:
# {(10, 10.5): 'dhaka', (20.5, 192): 'chattogram', (101, 102): 'sylhet'}

# %% [markdown]
# ## Problem Solving with In Built Structures
# #1. Given a list of numbers, make a list with unique values.

# %%
lst = [10 , 20 , 10 , 30 , 30 , 50 , 30 , 10 , 20 , 10 , 10 ]

unique_values = set(lst) ## conversion

lst = list(unique_values) 

print(lst)
# Out:
# [10, 20, 50, 30]

# %%
string = """data science machine learning data analysis machine 
learning statistics data models data training data validation features
features labels preprocessing data augmentation models data optimization 
gradient descent neural networks data tensors matrices visualization 
exploration pandas numpy matplotlib seaborn scikitlearn tensorflow pytorch 
deployment inference production monitoring reproducibility experiments results 
metrics accuracy precision recall f1 cross validation data machine
"""

words = string.split()

count = {} 


for word in words:
    count[word]= count.get(word,0) +1  

for k,v in count.items():
    print(f"count of {k} is {v}")
# Out:
# count of data is 9
# count of science is 1
# count of machine is 3
# count of learning is 2
# count of analysis is 1
# count of statistics is 1
# count of models is 2
# count of training is 1
# count of validation is 2
# count of features is 2
# count of labels is 1
# count of preprocessing is 1
# count of augmentation is 1
# count of optimization is 1
# count of gradient is 1
# count of descent is 1
# count of neural is 1
# count of networks is 1
# count of tensors is 1
# count of matrices is 1
# count of visualization is 1
# count of exploration is 1
# count of pandas is 1
# count of numpy is 1
# count of matplotlib is 1
# count of seaborn is 1
# count of scikitlearn is 1
# count of tensorflow is 1
# count of pytorch is 1
# count of deployment is 1
# count of inference is 1
# count of production is 1
# count of monitoring is 1
# count of reproducibility is 1
# count of experiments is 1
# count of results is 1
# count of metrics is 1
# count of accuracy is 1
# count of precision is 1
# count of recall is 1
# count of f1 is 1
# count of cross is 1
