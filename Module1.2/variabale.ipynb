# %%
id_number = 617
print(id_number)
# Out:
# 617

# %%
name = "Phiron AIML"

print(name)
# Out:
# Phiron AIML

# %%
#variable derclare
name = "Razib Miah"
age = 22
department = "CSE"
time = 3.29
bool = True
print(name,age,department)

#data type
print(type(name),type(age),type(time),type(bool))
# Out:
# Razib Miah 22 CSE
# <class 'str'> <class 'int'> <class 'float'> <class 'bool'>
