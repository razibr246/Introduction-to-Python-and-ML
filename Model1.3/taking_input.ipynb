# %% [markdown]
# Typing the Input in python

# %%
why = input("Why are you learning AIML?")
print(why)
# Out:
# To Marry Nafisa

# %%
Year = input("Year I want to marry Her!!")
print(Year,type(Year))
# Out:
# 2029 <class 'str'>

# %%
Year = input("Year ?") #String hisebe input nis

Year = int(Year) #string k amer int a concer korlam

print(Year,type(Year))
# Out:
# 2029 <class 'int'>

# %%
Month = input("Month ?")

print(Month,type(Month))
# Out:
# 3 <class 'str'>

# %%
Time = float(input("Time ?")) #string

print(Time,type(Time))

Time = Time + 0.12

print(Time)
# Out:
# 3.4 <class 'float'>
# 3.52
