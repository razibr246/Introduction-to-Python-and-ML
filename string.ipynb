# %%
my_str = "hello world"

print(my_str[4])
print(my_str[0])
print(my_str[3])
# Out:
# o
# h
# l

# %% [markdown]
# string[start:stop]

# %%
my_str = 'hello wordl-: I am ChatGPT'
print(my_str[1:5])
print(my_str[:5])
print(my_str[8:])
print(my_str)
print(my_str[:])
print(my_str[1:8:2])
print(my_str[::-1])
# Out:
# ello
# hello
# rdl-: I am ChatGPT
# hello wordl-: I am ChatGPT
# hello wordl-: I am ChatGPT
# el o
# TPGtahC ma I :-ldrow olleh

# %% [markdown]
# ### What Are Some Common String Methods?

# %%
my_str = 'Hello World'

upper_my_str  = my_str.upper()

print(upper_my_str)
# Out:
# HELLO WORLD

# %%
ymy_str = "MARK WOOD"

lower_my_str = my_str.lower()

print(lower_my_str)
# Out:
# mark wood

# %%
my_str = '  Hello World  '
#
trimmed_my_str = my_str.strip()

print(trimmed_my_str)
# Out:
# Hello World

# %%
my_str = 'Hello nice'

replaced_my_str = my_str.replace('nice','nafisa')

print(replaced_my_str)
# Out:
# Hello nafisa

# %%
my_str = "Tumi amer sobno sarothi"

split_str = my_str.split()

print(split_str)
# Out:
# ['Tumi', 'amer', 'sobno', 'sarothi']

# %%
my_list = ['Tomer','jona','ami','porsoan ','korta','raji']

join_my_list = ' '.join(my_list)

print(join_my_list)
# Out:
# Tomer jona ami porsoan  korta raji

# %%
my_str = 'Hello World'


starts_with_hello = my_str.startswith('hell')

print(starts_with_hello)
# Out:
# False

# %%
my_str = 'hello world'

ends_with_world = my_str.endswith('world')
print(ends_with_world)  # True
# Out:
# True

# %%
my_str = 'hello world'

world_index = my_str.find('world')
print(world_index)  # 6
# Out:
# 6

# %% [markdown]
# ### count(substring): Returns the number of times a substring appears in a string.

# %%
my_str = 'hello world'

o_count = my_str.count('o')
print(o_count)  # 2
# Out:
# 2

# %%
my_str = 'hello world'

capitalized_my_str = my_str.capitalize()
print(capitalized_my_str)  # Hello world
# Out:
# Hello world

# %%
my_str = 'hello world'

is_all_upper = my_str.isupper()
print(is_all_upper)  # False
# Out:
# False

# %%
my_str = 'hello world'

is_all_lower = my_str.islower()
print(is_all_lower)  # True
# Out:
# True

# %%
my_str = 'hello world'

title_case_my_str = my_str.title()
print(title_case_my_str)  # Hello World
# Out:
# Hello World
